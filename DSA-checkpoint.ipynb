# %%
# kdTree

class Node:
    def __init__(self, index, coords):
        self.index = index
        self.coords = coords

def mFaceSurface(r, f):
    # Your implementation
    pass

def nextAtom(u, d):
    # Your implementation
    pass

def overlap(o, v):
    # Your implementation
    pass

def intersection(o, q):
    # Your implementation
    pass

def findOverlappingNodes(nodes, o):
    L = set()
    S = [0]

    while S:
        current_index = S.pop()
        current_node = nodes[current_index]
        r = intersection(o, current_node.coords)

        for i, node in enumerate(nodes):  
            if i != current_index:
                v = node.coords

                if overlap(o.coords, v):
                    L.add(i)
                    if i not in L:
                        S.append(i)

    return L

# Example usage:
mesh_nodes = [(0, 0), (1, 0), (1, 1), (0, 1)]
nodes = [Node(i, coords) for i, coords in enumerate(mesh_nodes)]

# Select a node for testing
test_node_index = 0
test_orthotope = Node(test_node_index, mesh_nodes[test_node_index])

# Apply findOverlappingNodes
overlapping_node_indices = findOverlappingNodes(nodes, test_orthotope)

# Segregate overlapping and non-overlapping points
overlapping_coords = [nodes[i].coords for i in overlapping_node_indices]
non_overlapping_coords = [node.coords for i, node in enumerate(nodes) if i not in overlapping_node_indices]

print("Overlapping Coordinates:", overlapping_coords)
print("Non-Overlapping Coordinates:", non_overlapping_coords)

import matplotlib.pyplot as plt

# Check if lists are not empty before unpacking
if mesh_nodes:
    mesh_x, mesh_y = zip(*mesh_nodes)
else:
    mesh_x, mesh_y = [], []

if overlapping_coords:
    overlapping_x, overlapping_y = zip(*overlapping_coords)
else:
    overlapping_x, overlapping_y = [], []

if non_overlapping_coords:
    non_overlapping_x, non_overlapping_y = zip(*non_overlapping_coords)
else:
    non_overlapping_x, non_overlapping_y = [], []

# Plot the triangular mesh
plt.figure()
plt.triplot(mesh_x, mesh_y, marker='o', markersize=5, color='blue', label='Mesh Nodes')

# Plot overlapping and non-overlapping points
plt.scatter(overlapping_x, overlapping_y, marker='x', color='red', label='Overlapping Points')
#plt.scatter(non_overlapping_x, non_overlapping_y, marker='^', color='green', label='Non-Overlapping Points')

plt.title('Triangular Mesh with Overlapping and Non-Overlapping Points')
plt.xlabel('Velocity')
plt.ylabel('Pressure')
plt.legend(loc = 'upper right')
plt.gca().set_aspect('equal', adjustable='box')
plt.show()
# Out:
# Overlapping Coordinates: []
# Non-Overlapping Coordinates: [(0, 0), (1, 0), (1, 1), (0, 1)]

# %%
# Example usage:
mesh_nodes = [(0, 0), (1, 0), (1, 1), (0, 1)]
nodes = [Node(i, coords) for i, coords in enumerate(mesh_nodes)]

# Select a node for testing
test_node_index = 0
test_orthotope = Node(test_node_index, mesh_nodes[test_node_index])

# Apply findOverlappingNodes
overlapping_node_indices = findOverlappingNodes(nodes, test_orthotope)

# Remove overlapping nodes from the original list
filtered_nodes = [node for i, node in enumerate(nodes) if i not in overlapping_node_indices]

# Segregate non-overlapping points
filtered_coords = [node.coords for node in filtered_nodes]

print("Filtered Coordinates (No Overlapping):", filtered_coords)

# Plot the triangular mesh without overlapping nodes
if filtered_coords:
    filtered_x, filtered_y = zip(*filtered_coords)
else:
    filtered_x, filtered_y = [], []

plt.figure()
plt.triplot(mesh_x, mesh_y, marker='o', markersize=5, color='blue', label='Mesh Nodes')
plt.scatter(filtered_x, filtered_y, marker='^', color='green', label='Non-Overlapping Points')

plt.title('Triangular Mesh without Overlapping Nodes')
plt.xlabel('Velocity')
plt.ylabel('Pressure')
plt.legend(loc = 'upper right')
plt.gca().set_aspect('equal', adjustable='box')
plt.show()
# Out:
# Filtered Coordinates (No Overlapping): [(0, 0), (1, 0), (1, 1), (0, 1)]

# %%
# List 
class Node:
    def __init__(self, index, coords):
        self.index = index
        self.coords = coords

def mFaceSurface(r, f):
    # Your implementation
    pass

def nextAtom(u, d):
    # Your implementation
    pass

def overlap(o, v):
    # Your implementation
    pass

def intersection(o, q):
    # Your implementation
    pass

def findOverlappingNodes(nodes, o):
    L = set()
    S = [0]

    while S:
        current_index = S.pop()
        current_node = nodes[current_index]
        r = intersection(o, current_node.coords)

        for i, node in enumerate(nodes):  
            if i != current_index:
                v = node.coords

                if overlap(o.coords, v):
                    L.add(i)
                    if i not in L:
                        S.append(i)

    return L

# Example usage:
mesh_nodes = [(0, 0), (1, 0), (1, 1), (0, 1)]
nodes = [Node(i, coords) for i, coords in enumerate(mesh_nodes)]

# Select a node for testing
test_node_index = 0
test_orthotope = Node(test_node_index, mesh_nodes[test_node_index])

# Apply findOverlappingNodes
overlapping_node_indices = findOverlappingNodes(nodes, test_orthotope)

# Segregate overlapping and non-overlapping points
overlapping_coords = [nodes[i].coords for i in overlapping_node_indices]
non_overlapping_coords = [node.coords for i, node in enumerate(nodes) if i not in overlapping_node_indices]

print("Overlapping Coordinates:", overlapping_coords)
print("Non-Overlapping Coordinates:", non_overlapping_coords)

import matplotlib.pyplot as plt

# Check if lists are not empty before unpacking
if mesh_nodes:
    mesh_x, mesh_y = zip(*mesh_nodes)
else:
    mesh_x, mesh_y = [], []

if overlapping_coords:
    overlapping_x, overlapping_y = zip(*overlapping_coords)
else:
    overlapping_x, overlapping_y = [], []

if non_overlapping_coords:
    non_overlapping_x, non_overlapping_y = zip(*non_overlapping_coords)
else:
    non_overlapping_x, non_overlapping_y = [], []

# Plot the triangular mesh
plt.figure()
plt.triplot(mesh_x, mesh_y, marker='o', markersize=5, color='blue', label='Mesh Nodes')

# Plot overlapping and non-overlapping points
plt.scatter(overlapping_x, overlapping_y, marker='x', color='red', label='Overlapping Points')
plt.scatter(non_overlapping_x, non_overlapping_y, marker='^', color='green', label='Non-Overlapping Points')

plt.title('Triangular Mesh with Overlapping and Non-Overlapping Points')
plt.xlabel('Velocity')
plt.ylabel('Pressure')
plt.legend(loc = 'upper right')
plt.gca().set_aspect('equal', adjustable='box')
plt.show()
# Out:
# Overlapping Coordinates: []
# Non-Overlapping Coordinates: [(0, 0), (1, 0), (1, 1), (0, 1)]

# %%
class Node:
    def __init__(self, index, coords):
        self.index = index
        self.coords = coords

def mFaceSurface(r, f):
    # Your implementation
    pass

def nextAtom(u, d):
    # Your implementation
    pass

def overlap(o, v):
    # Your implementation
    pass

def intersection(o, q):
    # Your implementation
    pass

def removeOverlappingNodes(nodes, o):
    overlapping_node_indices = findOverlappingNodes(nodes, o)
    filtered_nodes = [node for i, node in enumerate(nodes) if i not in overlapping_node_indices]
    return filtered_nodes

# Example usage:
mesh_nodes = [(0, 0), (1, 0), (1, 1), (0, 1)]
nodes = [Node(i, coords) for i, coords in enumerate(mesh_nodes)]

# Select a node for testing
test_node_index = 0
test_orthotope = Node(test_node_index, mesh_nodes[test_node_index])

# Remove overlapping nodes
filtered_nodes = removeOverlappingNodes(nodes, test_orthotope)

# Segregate non-overlapping points
filtered_coords = [node.coords for node in filtered_nodes]

print("Filtered Coordinates (No Overlapping):", filtered_coords)

# Plot the triangular mesh without overlapping nodes
if filtered_coords:
    filtered_x, filtered_y = zip(*filtered_coords)
else:
    filtered_x, filtered_y = [], []

import matplotlib.pyplot as plt

plt.figure()
plt.triplot(filtered_x, filtered_y, marker='o', markersize=5, color='blue', label='Mesh Nodes (No Overlapping)')
plt.scatter(filtered_x, filtered_y, marker='^', color='green', label='Non-Overlapping Points')

plt.title('Triangular Mesh without Overlapping Nodes')
plt.xlabel('Velocity')
plt.ylabel('Pressure')
plt.legend(loc = 'upper right')
plt.gca().set_aspect('equal', adjustable='box')
plt.show()
# Out:
# Filtered Coordinates (No Overlapping): [(0, 0), (1, 0), (1, 1), (0, 1)]

# %%
import numpy as np
from scipy.spatial import cKDTree
import matplotlib.pyplot as plt

class Node:
    def __init__(self, index, coords):
        self.index = index
        self.coords = coords

class KdTree:
    def __init__(self, nodes):
        self.leaves = [Node(i, coords) for i, coords in enumerate(nodes)]
        self.tree = cKDTree([node.coords for node in self.leaves])

# Given functions
def firstAtom(o):
    return o.coords

def binarySearchOverlapping(T, f):
    _, index = T.tree.query(f)
    return index

def mFaceSurface(r, f):
    # Your implementation
    pass

def nextAtom(u, d):
    # Your implementation
    pass

def overlap(o, v):
    # Your implementation
    pass

def intersection(o, q):
    # Your implementation
    pass

def removeOverlappingNodes(T, nodes_to_remove):
    remaining_nodes = [node for i, node in enumerate(T.leaves) if i not in nodes_to_remove]
    return KdTree([node.coords for node in remaining_nodes])

# Example usage:
# Assuming you have a mesh (nodes) and a kd-tree (kd_tree) created
mesh_nodes = [(0, 0), (1, 0), (1, 1), (0, 1)]
kd_tree = KdTree(mesh_nodes)

# Select a node for testing
test_node_index = 0
test_orthotope = Node(test_node_index, mesh_nodes[test_node_index])

# Apply findOverlappingNodes
overlapping_node_indices = findOverlappingNodes(kd_tree, test_orthotope)

# Remove overlapping nodes from the kd-tree
filtered_kd_tree = removeOverlappingNodes(kd_tree, overlapping_node_indices)

# Plot the modified triangular mesh without overlapping nodes
if filtered_kd_tree.leaves:
    filtered_mesh_x, filtered_mesh_y = zip(*[node.coords for node in filtered_kd_tree.leaves])
    plt.figure()
    plt.triplot(filtered_mesh_x, filtered_mesh_y, marker='o', markersize=5, color='blue', label='Filtered Mesh Nodes')
    plt.title('Triangular Mesh without Overlapping Nodes')
    plt.xlabel('X')
    plt.ylabel('Y')
    plt.legend()
    plt.gca().set_aspect('equal', adjustable='box')
    plt.show()
else:
    print("No nodes remaining after removing overlapping nodes.")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 53
#      50 test_orthotope = Node(test_node_index, mesh_nodes[test_node_index])
#      52 # Apply findOverlappingNodes
# ---> 53 overlapping_node_indices = findOverlappingNodes(kd_tree, test_orthotope)
#      55 # Remove overlapping nodes from the kd-tree
#      56 filtered_kd_tree = removeOverlappingNodes(kd_tree, overlapping_node_indices)
#
# Cell In[15], line 29, in findOverlappingNodes(nodes, o)
#      27 while S:
#      28     current_index = S.pop()
# ---> 29     current_node = nodes[current_index]
#      30     r = intersection(o, current_node.coords)
#      32     for i, node in enumerate(nodes):
#
# TypeError: 'KdTree' object is not subscriptable

# %%
class Node:
    def __init__(self, index, coords):
        self.index = index
        self.coords = coords

class KdTree:
    def __init__(self, nodes):
        self.leaves = [Node(i, coords) for i, coords in enumerate(nodes)]

# Assume you have these functions defined
def firstAtom(o):
    # Your implementation
    pass

def binarySearchOverlapping(T, f):
    # Your implementation
    pass

def mFaceSurface(r, f):
    # Your implementation
    pass

def nextAtom(u, d):
    # Your implementation
    pass

def overlap(o, v):
    # Your implementation
    pass

def intersection(o, q):
    # Your implementation
    pass

def findOverlappingNodes(T, o):
    L = set()  # Unique set of overlapping nodes
    S = [0]  # Stack of nodes to visit, initialized with the root index

    while S:
        current_index = S.pop()
        current_node = T.leaves[current_index]
        r = intersection(o, current_node.coords)  # Use 'coords' attribute

        for d in range(2):  # Assuming 2D for simplicity
            f = [1] * 2
            f[d] = -1  # Request 'first' corner in dimension d
            u = mFaceSurface(r, f)
            v = nextAtom(u, d)

            if overlap(o.coords, v):  # Use 'coords' attribute
                k = binarySearchOverlapping(T, v)
                L.add(k)
                if k not in L:
                    S.append(k)

    return L

# Example usage:
# Assuming you have a mesh (nodes) and a kd-tree (T) created
mesh_nodes = [(0, 0), (1, 0), (1, 1), (0, 1)]
kd_tree = KdTree(mesh_nodes)

# Select a node for testing
test_node_index = 0
test_orthotope = Node(test_node_index, mesh_nodes[test_node_index])

# Apply findOverlappingNodes
overlapping_nodes = findOverlappingNodes(kd_tree, test_orthotope)
print("Overlapping Nodes:", overlapping_nodes)
# Out:
# Overlapping Nodes: set()

# %%
import matplotlib.pyplot as plt

class Node:
    def __init__(self, index, coords):
        self.index = index
        self.coords = coords

class KdTree:
    def __init__(self, nodes):
        self.leaves = [Node(i, coords) for i, coords in enumerate(nodes)]

# Example usage:
# Assuming you have a mesh (nodes) and a kd-tree (T) created
mesh_nodes = [(0, 0), (1, 0), (1, 1), (0, 1)]
kd_tree = KdTree(mesh_nodes)

# Plot the mesh
plt.figure()
plt.scatter(*zip(*mesh_nodes), marker='o', color='blue', label='Mesh Nodes')

# Highlight the overlapping nodes found by findOverlappingNodes
test_node_index = 0
test_orthotope = Node(test_node_index, mesh_nodes[test_node_index])
overlapping_nodes = {1, 2}  # Replace this with the actual overlapping nodes
overlapping_coords = [kd_tree.leaves[i].coords for i in overlapping_nodes]
plt.scatter(*zip(*overlapping_coords), marker='x', color='red', label='Overlapping Nodes')

plt.title('Mesh with Overlapping Nodes')
plt.xlabel('Velocity')
plt.ylabel('Pressure')
plt.legend()
plt.gca().set_aspect('equal', adjustable='box')
plt.show()
